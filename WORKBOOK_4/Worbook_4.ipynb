# %% [markdown]
# EXERCISES Exercise 1
#
# Adapted from [TCS] Appendix D, Exercise 2
#
# Open help for the math module.

# %%
What are the constants in the math module? # The constants in the math module are:
    # e = 2.718281828459045
   # inf = inf
   # nan = nan
    #pi = 3.141592653589793
    #tau = 6.283185307179586

What's does math.exp do? What about math.pow?
# math.exp(x) calculates e**x, where e is a special number approximately equal to 2.71828. It's raised to the power of x.
#while the math.pow(x, y) calculates x**y. It means x is raised to the power of y.

How do you calculate logarithms? Logarithms base 10? Natural Logarithms?
#lgamma(x, /) Natural logarithm of absolute value of Gamma function at x.
#log(...) log(x, [base=math.e]) Return the logarithm of x to the given base.
#If the base not specified, returns the natural logarithm (base e) of x.
# log10(x, /) Return the base 10 logarithm of x.

# %% [markdown]
# Exercise 2

# %%
Create your own module.
Place variables and functions inside it.
Import your module and use the variabls and functions you've created in the module.
Try to add docstrings for the module and the functions

# %%
# %%writefile operations.py
"""
A module for various mathematical operations
"""

def calculate_mean(numbers):
    """
    Calculate the mean of a list of numbers.

    Parameters:
    numbers (list): A list of numerical values.

    Returns:
    float: The mean of the input list.
    """
    if not numbers:
        return None
    return sum(numbers) / len(numbers)

def calculate_standard_deviation(numbers):
    """
    Calculate the standard deviation of a list of numbers.

    Parameters:
    numbers (list): A list of numerical values.

    Returns:
    float: The standard deviation of the input list.
    """
    if not numbers:
        return None
    mean = calculate_mean(numbers)
    variance = sum((x - mean) ** 2 for x in numbers) / len(numbers)
    return variance ** 0.5

def calculate_median(numbers):
    """
    Calculate the median of a list of numbers.

    Parameters:
    numbers (list): A list of numerical values.

    Returns:
    float: The median of the input list.
    """
    if not numbers:
        return None
    sorted_numbers = sorted(numbers)
    n = len(sorted_numbers)
    if n % 2 == 0:
        return (sorted_numbers[n // 2 - 1] + sorted_numbers[n // 2]) / 2
    else:
        return sorted_numbers[n // 2]
# Out:
# Writing operations.py

# %%
# !dir operations.py
# Out:
# operations.py

# %%
import operations

# %%
operations.calculate_mean([9, 41, 12, 3, 74, 15])
# Out:
# 25.666666666666668

# %%
operations.calculate_median([9, 41, 12, 3, 74, 15])
# Out:
# 13.5

# %%
operations.calculate_standard_deviation([9, 41, 12, 3, 74, 15])
# Out:
# 24.709422404328993

# %%
help(operations)
# Out:
# Help on module operations:
#
# NAME
#     operations - A module for various mathematical operations
#
# FUNCTIONS
#     calculate_mean(numbers)
#         Calculate the mean of a list of numbers.
#
#         Parameters:
#         numbers (list): A list of numerical values.
#
#         Returns:
#         float: The mean of the input list.
#
#     calculate_median(numbers)
#         Calculate the median of a list of numbers.
#
#         Parameters:
#         numbers (list): A list of numerical values.
#
#         Returns:
#         float: The median of the input list.
#
#     calculate_standard_deviation(numbers)
#         Calculate the standard deviation of a list of numbers.
#
#         Parameters:
#         numbers (list): A list of numerical values.
#
#         Returns:
#         float: The standard deviation of the input list.
#
# FILE
#     /content/operations.py
