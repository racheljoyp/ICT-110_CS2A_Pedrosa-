# %% [markdown]
# Chapter 1
#
# Exercise 1
#
# Each line of code below contains an error. Fix the error and explain in a comment the reason for the error.
#
# 1.

# %%
Print('Hello world!') #the word print is in capital letter
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3a7ff792b807> in <cell line: 1>()
# ----> 1 Print('Hello world!') #the word print is in capital letter
#
# NameError: name 'Print' is not defined

# %% [markdown]
# answer:

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# 2.

# %%
print'Hello world!') #this code lacks parenthesis

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# 3.

# %%
print('Hello world!) #this code lacks apostrophe because it is a string and it needs apostrophe

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# 4

# %%
print('Hello world!'') #the code has an extra apostrophe at the end

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# Exercise 2
# What is the output of the code below?

# %%
x = 43
x = x + 1
x # print (x)
# Out:
# 44

# %% [markdown]
# Exercise 3

# %%
x = 43
x = X + 1
print(x) # The variable in X+1 is in capital letter, so i changed the variable to lowercase
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-05dcd2cba464> in <cell line: 2>()
#       1 x = 43
# ----> 2 x = X + 1
#       3 print(x) # The variable in X+1 is in capital letter, so i changed the variable to lowercase
#
# NameError: name 'X' is not defined

# %%
#answer
x = 43
x = x + 1
print(x)
# Out:
# 44
