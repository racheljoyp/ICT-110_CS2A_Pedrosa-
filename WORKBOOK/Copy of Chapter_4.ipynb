# %% [markdown]
# EXERCISES
# Exercise 1
#
# Rewrite your pay computation with time-and-a-half for overtime and create a function called compute pay which takes two parameters (hours and rate).

# %%
salary = input(" Enter Hours: ")
rate = input ("Enter rate: ")

if int(salary) > 40:
   pay = int(salary) *int(rate)

else :
  print("you didn't reach the minimum hours worked")

print ("Pay: ",float(pay))

# %% [markdown]
# Challenge
#
# Write a function called computegrade that takes a score as its parameter and returns a grade as a string using the following table:
#
# Score           Grade
# [ 97, 100]      1.0
# [ 93,  97)        1.25
# [ 89,  93)        1.5
# [ 85,  89)        1.75
# [ 81,  85)        2.0
# [ 77,  81)        2.25
# [ 74,  77)        2.5
# [ 0,   74)        3.0
#
# Run the program repeatedly to test the various different values for input.

# %%
def computer_grade(score):
    if int(score) > 97 and int(score) < 100:
        computer_grade()
        print("Yes, I will.")
    elif score == 'spring':
        computer_grade()
        print("Oh, yeah!")
    elif score is 'summer':
        computer_grade()
        print("Ain't it good to know?")
    elif score is 'fall':
        computer_grade()
        print("You've got a friend!")
    else:
        print('Who u?')
# Out:
# <>:8: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:8: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-12-e81ab380d325>:8: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif score is 'summer':
# <ipython-input-12-e81ab380d325>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif score is 'fall':
