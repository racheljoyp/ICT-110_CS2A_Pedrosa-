# %% [markdown]
# EXERCISES
# Exercise 1
#
# Create a tuple with the following items: 1, 1, 2, 3, 5. Feed the tuple to the sum() built-in function and check the result.

# %%
items = (1,1,2,3,5)
print(items)

result=sum(items)
print(result)
# Out:
# (1, 1, 2, 3, 5)
# 12

# %% [markdown]
# Exercise 2

# %% [markdown]
# Unpack the following tuple into meaningful variables and display them

# %%
ph_info = ('Philippines', 'Manila', 103.3) # The last number is the Population in Millions as of 2016

# %%
country, capital, population = ph_info
print("The capital city of", country,"is", capital,".")
print("The population in Millions of the country as of 2016:",population,".")
# Out:
# The capital city of Philippines is Manila .
# The population in Millions of the country as of 2016: 103.3 .
