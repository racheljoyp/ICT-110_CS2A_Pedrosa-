# %% [markdown]
# EXERCISES
# Exercise 1

# %%
text = 'Business Analytics'

text[4]
text[2:4]
text[:4]
text[4:]
text[-2]
text[-4:-2]
text[-2:]
text[:-2]

# %%
#answer
text = 'Business Analytics'

print(text[4])
print(text[2:4])
print(text[4:])
print(text[:4])
print(text[-2])
print(text[-4:-2])
print(text[-2:])
print(text[:-2])
# Out:
# n
# si
# ness Analytics
# Busi
# c
# ti
# cs
# Business Analyti

# %% [markdown]
# Exercise 2

# %%
phrase = 'One Ring to rule them all'

# %%
What string slicing expression gives out the following words:

'One '
'Ring'
'all'
'them'
'One Ring to rule them all'

# %%
phrase = 'One Ring to rule them all'


phrase1 = phrase[:4]
phrase2 = phrase[4:8]
phrase3 = phrase[-3:]
phrase4 = phrase[17:21]
phrase5 = phrase[:]

print(phrase1)
print(phrase2)
print(phrase3)
print(phrase4)
print(phrase5)
# Out:
# One
# Ring
# all
# them
# One Ring to rule them all

# %% [markdown]
# CHALLENGE
#
# Write a program which repeatedly reads a full name, then does the following:
#
# strips the name of any trailing spaces
#
# capitalizes the first letter
#
# puts the rest into smaller letters

# %%
for n in range(10) :
  name = input("Enter your full name: ")

  print(name.strip().capitalize())
# Out:
# Enter your full name: rachel
# Rachel
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-a36e416c439c> in <cell line: 1>()
#       1 for n in range(10) :
# ----> 2   name = input("Enter your full name: ")
#       3
#       4   print(name.strip().capitalize())
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
