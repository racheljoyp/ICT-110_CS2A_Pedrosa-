# %% [markdown]
# EXERCISES
#
# Exercise 1

# %% [markdown]
# Write a program to read through a file and print the contents of the file (line by line) all in upper case.
#
# from [PEW] E8-1

# %%
file_name = input("Enter file name: ")

try:
    with open(file_name, 'r') as file:
        for line in file:
            print(line.upper(), end='')

except FileNotFoundError:
    print("File not found.")
# Out:
# Enter file name: /content/drive/MyDrive/Workbook_2/hello.txt
# HELLO, WORLD!

# %% [markdown]
# Exercise 2
#
# Write a program to read through a file and output the number of lines in a file.
#
# adapted from [PEW]

# %%
file_name = input("Ente file name: ")

try:
    with open(file_name, 'r') as file:
        line_count = sum(1 for line in file)
    print("Number of lines in the file:", line_count)
except FileNotFoundError:
    print("File not found.")
# Out:
# Ente file name: /content/drive/MyDrive/Workbook_2/hello.txt
# Number of lines in the file: 1
